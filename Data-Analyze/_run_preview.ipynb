# %%
# %%capture
# %load_ext autoreload
# %autoreload 2
# %reset -f

# %% [markdown]
# #### **Import required libraries**

# %%
import logging
import os
import json

# %% [markdown]
# #### **Import utilities and configurations**

# %%
from agents import Agents
from pathlib import Path
from helpers import (
    clean_agent_output,
)

# %% [markdown]
# #### **Model Config**

# %%
model: str = "gemini/gemini-2.0-flash-exp"
api_key: str = os.getenv("GEMINI_API_KEY")
temperature: float = 0.1
top_p: float = 0.85

# %% [markdown]
# #### **Inicial Setup**

# %%
logger = logging.getLogger("poc_presentations")
agents = Agents(model, api_key, temperature, top_p)

# %%
data_to_analyze = {
    "total_items_considered": 3,
    "total_items_approved": 3,
    "total_items_refused": 0,
    "percentage_approved": "100.0%",
    "percentage_refused": "0.0%",
    "global_ai_accuracy": {
        "total_fields_considered": 225,
        "total_fields_corrected": 38,
        "total_fields_correct": 187,
        "accuracy_rate_percent": "83.11%"
    },
    "full_review_index": {
        "items_with_no_corrections": 0,
        "items_needing_correction": 3,
        "percent_no_corrections_needed": "0.0%",
        "percent_corrections_needed": "100.0%"
    },
    "field_change_ranking": {
        "hiringType": {
            "total_changes_across_items": 3,
            "percentage_of_considered_items": "100.0%"
        },
        "startValidity": {
            "total_changes_across_items": 3,
            "percentage_of_considered_items": "100.0%"
        },
        "totalRiskValue": {
            "total_changes_across_items": 3,
            "percentage_of_considered_items": "100.0%"
        },
        "endValidity": {
            "total_changes_across_items": 3,
            "percentage_of_considered_items": "100.0%"
        },
        "personType": {
            "total_changes_across_items": 3,
            "percentage_of_considered_items": "100.0%"
        },
        "mainFramingCode": {
            "total_changes_across_items": 3,
            "percentage_of_considered_items": "100.0%"
        },
        "coverages.8.code": {
            "total_changes_across_items": 3,
            "percentage_of_considered_items": "100.0%"
        },
        "items.0.activityCode": {
            "total_changes_across_items": 3,
            "percentage_of_considered_items": "100.0%"
        },
        "items.0.activity": {
            "total_changes_across_items": 3,
            "percentage_of_considered_items": "100.0%"
        },
        "coverages.7.indemnityPeriod": {
            "total_changes_across_items": 1,
            "percentage_of_considered_items": "33.33%"
        },
        "coverages.8.indemnityPeriod": {
            "total_changes_across_items": 1,
            "percentage_of_considered_items": "33.33%"
        },
        "coverages.1.indemnityPeriod": {
            "total_changes_across_items": 1,
            "percentage_of_considered_items": "33.33%"
        },
        "coverages.6.indemnityPeriod": {
            "total_changes_across_items": 1,
            "percentage_of_considered_items": "33.33%"
        },
        "coverages.2.indemnityPeriod": {
            "total_changes_across_items": 1,
            "percentage_of_considered_items": "33.33%"
        },
        "coverages.9.indemnityPeriod": {
            "total_changes_across_items": 1,
            "percentage_of_considered_items": "33.33%"
        },
        "coverages.3.indemnityPeriod": {
            "total_changes_across_items": 1,
            "percentage_of_considered_items": "33.33%"
        },
        "coverages.4.indemnityPeriod": {
            "total_changes_across_items": 1,
            "percentage_of_considered_items": "33.33%"
        },
        "coverages.10.indemnityPeriod": {
            "total_changes_across_items": 1,
            "percentage_of_considered_items": "33.33%"
        },
        "coverages.5.indemnityPeriod": {
            "total_changes_across_items": 1,
            "percentage_of_considered_items": "33.33%"
        },
        "coverages.0.indemnityPeriod": {
            "total_changes_across_items": 1,
            "percentage_of_considered_items": "33.33%"
        }
    },
    "items_timeline": {
        "1": {
            "total_fields_changed": 9,
            "timeline": {
                "coverages.8.code": [
                    {
                        "source": "initial_inference",
                        "value": "N/A",
                        "timestamp": "2025-04-11T13:10:45.101Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "00965",
                        "timestamp": "2025-04-11T14:22:42.247Z"
                    }
                ],
                "endValidity": [
                    {
                        "source": "initial_inference",
                        "value": "10/06/2024",
                        "timestamp": "2025-04-11T13:10:45.101Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "2024-06-10",
                        "timestamp": "2025-04-11T14:22:42.247Z"
                    }
                ],
                "hiringType": [
                    {
                        "source": "initial_inference",
                        "value": "LMI Único",
                        "timestamp": "2025-04-11T13:10:45.101Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": None,
                        "timestamp": "2025-04-11T14:22:42.247Z"
                    }
                ],
                "items.0.activity": [
                    {
                        "source": "initial_inference",
                        "value": "N/A",
                        "timestamp": "2025-04-11T13:10:45.101Z"
                    },
                    {
                        "update_source": "2nd Correction",
                        "value": "AÇUCAR - DEPÓSITO",
                        "timestamp": "2025-04-11T14:22:52.078Z"
                    }
                ],
                "items.0.activityCode": [
                    {
                        "source": "initial_inference",
                        "value": "N/A",
                        "timestamp": "2025-04-11T13:10:45.101Z"
                    },
                    {
                        "update_source": "2nd Correction",
                        "value": "002-11",
                        "timestamp": "2025-04-11T14:22:52.078Z"
                    }
                ],
                "mainFramingCode": [
                    {
                        "source": "initial_inference",
                        "value": "52.12-5-00",
                        "timestamp": "2025-04-11T13:10:45.101Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": None,
                        "timestamp": "2025-04-11T14:22:42.247Z"
                    }
                ],
                "personType": [
                    {
                        "source": "initial_inference",
                        "value": "Jurídica",
                        "timestamp": "2025-04-11T13:10:45.101Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": None,
                        "timestamp": "2025-04-11T14:22:42.247Z"
                    }
                ],
                "startValidity": [
                    {
                        "source": "initial_inference",
                        "value": "10/06/2023",
                        "timestamp": "2025-04-11T13:10:45.101Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "2023-06-10",
                        "timestamp": "2025-04-11T14:22:42.247Z"
                    }
                ],
                "totalRiskValue": [
                    {
                        "source": "initial_inference",
                        "value": "R$ 62.500.000,00",
                        "timestamp": "2025-04-11T13:10:45.101Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": None,
                        "timestamp": "2025-04-11T14:22:42.247Z"
                    }
                ]
            }
        },
        "10": {
            "total_fields_changed": 20,
            "timeline": {
                "coverages.0.indemnityPeriod": [
                    {
                        "source": "initial_inference",
                        "value": 0,
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "",
                        "timestamp": "2025-04-11T13:27:51.071Z"
                    }
                ],
                "coverages.1.indemnityPeriod": [
                    {
                        "source": "initial_inference",
                        "value": 0,
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "",
                        "timestamp": "2025-04-11T13:27:51.071Z"
                    }
                ],
                "coverages.10.indemnityPeriod": [
                    {
                        "source": "initial_inference",
                        "value": 0,
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "",
                        "timestamp": "2025-04-11T13:27:51.071Z"
                    }
                ],
                "coverages.2.indemnityPeriod": [
                    {
                        "source": "initial_inference",
                        "value": 0,
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "",
                        "timestamp": "2025-04-11T13:27:51.071Z"
                    }
                ],
                "coverages.3.indemnityPeriod": [
                    {
                        "source": "initial_inference",
                        "value": 0,
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "",
                        "timestamp": "2025-04-11T13:27:51.071Z"
                    }
                ],
                "coverages.4.indemnityPeriod": [
                    {
                        "source": "initial_inference",
                        "value": 0,
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "",
                        "timestamp": "2025-04-11T13:27:51.071Z"
                    }
                ],
                "coverages.5.indemnityPeriod": [
                    {
                        "source": "initial_inference",
                        "value": 0,
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "",
                        "timestamp": "2025-04-11T13:27:51.071Z"
                    }
                ],
                "coverages.6.indemnityPeriod": [
                    {
                        "source": "initial_inference",
                        "value": 0,
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "",
                        "timestamp": "2025-04-11T13:27:51.071Z"
                    }
                ],
                "coverages.7.indemnityPeriod": [
                    {
                        "source": "initial_inference",
                        "value": 0,
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "",
                        "timestamp": "2025-04-11T13:27:51.071Z"
                    }
                ],
                "coverages.8.code": [
                    {
                        "source": "initial_inference",
                        "value": "N/A",
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "4th Correction",
                        "value": "00035",
                        "timestamp": "2025-04-11T16:27:26.334Z"
                    }
                ],
                "coverages.8.indemnityPeriod": [
                    {
                        "source": "initial_inference",
                        "value": 0,
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "",
                        "timestamp": "2025-04-11T13:27:51.071Z"
                    }
                ],
                "coverages.9.indemnityPeriod": [
                    {
                        "source": "initial_inference",
                        "value": 0,
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "",
                        "timestamp": "2025-04-11T13:27:51.071Z"
                    }
                ],
                "endValidity": [
                    {
                        "source": "initial_inference",
                        "value": "10/06/2024",
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "2024-06-10",
                        "timestamp": "2025-04-11T13:27:51.071Z"
                    }
                ],
                "hiringType": [
                    {
                        "source": "initial_inference",
                        "value": "LMI Único",
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": None,
                        "timestamp": "2025-04-11T13:27:51.071Z"
                    }
                ],
                "items.0.activity": [
                    {
                        "source": "initial_inference",
                        "value": "N/A",
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "3rd Correction",
                        "value": "AÇOUGUE",
                        "timestamp": "2025-04-11T16:27:16.344Z"
                    }
                ],
                "items.0.activityCode": [
                    {
                        "source": "initial_inference",
                        "value": "N/A",
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "3rd Correction",
                        "value": "001-00",
                        "timestamp": "2025-04-11T16:27:16.344Z"
                    }
                ],
                "mainFramingCode": [
                    {
                        "source": "initial_inference",
                        "value": "52.12-5-00",
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": None,
                        "timestamp": "2025-04-11T13:27:51.071Z"
                    }
                ],
                "personType": [
                    {
                        "source": "initial_inference",
                        "value": "Jurídica",
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": None,
                        "timestamp": "2025-04-11T13:27:51.071Z"
                    }
                ],
                "startValidity": [
                    {
                        "source": "initial_inference",
                        "value": "10/06/2023",
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "2023-06-10",
                        "timestamp": "2025-04-11T13:27:51.071Z"
                    }
                ],
                "totalRiskValue": [
                    {
                        "source": "initial_inference",
                        "value": "R$ 62.500.000,00",
                        "timestamp": "2025-04-11T13:14:44.190Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": None,
                        "timestamp": "2025-04-11T13:27:51.071Z"
                    }
                ]
            }
        },
        "9": {
            "total_fields_changed": 9,
            "timeline": {
                "coverages.8.code": [
                    {
                        "source": "initial_inference",
                        "value": "N/A",
                        "timestamp": "2025-04-11T13:13:15.944Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "00972",
                        "timestamp": "2025-04-12T01:00:48.579Z"
                    }
                ],
                "endValidity": [
                    {
                        "source": "initial_inference",
                        "value": "10/06/2024",
                        "timestamp": "2025-04-11T13:13:15.944Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "2024-06-10",
                        "timestamp": "2025-04-12T01:00:48.579Z"
                    }
                ],
                "hiringType": [
                    {
                        "source": "initial_inference",
                        "value": "LMI Único",
                        "timestamp": "2025-04-11T13:13:15.944Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": None,
                        "timestamp": "2025-04-12T01:00:48.579Z"
                    }
                ],
                "items.0.activity": [
                    {
                        "source": "initial_inference",
                        "value": "N/A",
                        "timestamp": "2025-04-11T13:13:15.944Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "AÇUCAR - DEPÓSITO",
                        "timestamp": "2025-04-12T01:00:48.579Z"
                    },
                    {
                        "update_source": "2nd Correction",
                        "value": "ÁLCOOL E AÇÚCAR - USINA",
                        "timestamp": "2025-04-12T01:00:55.426Z"
                    }
                ],
                "items.0.activityCode": [
                    {
                        "source": "initial_inference",
                        "value": "N/A",
                        "timestamp": "2025-04-11T13:13:15.944Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "002-11",
                        "timestamp": "2025-04-12T01:00:48.579Z"
                    },
                    {
                        "update_source": "2nd Correction",
                        "value": "002-31",
                        "timestamp": "2025-04-12T01:00:55.426Z"
                    }
                ],
                "mainFramingCode": [
                    {
                        "source": "initial_inference",
                        "value": "52.12-5-00",
                        "timestamp": "2025-04-11T13:13:15.944Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": None,
                        "timestamp": "2025-04-12T01:00:48.579Z"
                    }
                ],
                "personType": [
                    {
                        "source": "initial_inference",
                        "value": "Jurídica",
                        "timestamp": "2025-04-11T13:13:15.944Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": None,
                        "timestamp": "2025-04-12T01:00:48.579Z"
                    }
                ],
                "startValidity": [
                    {
                        "source": "initial_inference",
                        "value": "10/06/2023",
                        "timestamp": "2025-04-11T13:13:15.944Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": "2023-06-10",
                        "timestamp": "2025-04-12T01:00:48.579Z"
                    }
                ],
                "totalRiskValue": [
                    {
                        "source": "initial_inference",
                        "value": "R$ 62.500.000,00",
                        "timestamp": "2025-04-11T13:13:15.944Z"
                    },
                    {
                        "update_source": "1st Correction",
                        "value": None,
                        "timestamp": "2025-04-12T01:00:48.579Z"
                    }
                ]
            }
        }
    }
}

# %% [markdown]
# #### **Process Agent**

# %%
result = agents.generate_analyze(data_to_analyze)
print(
    f"\n**Agente Result:**\n",
    result["pdf_path"]
)
# Out:
# # Agent: AI Performance Analyst
# ## Task: You are responsible for analyzing the performance data of our information extraction system, based on usage activity tracked within the platform.
# The input data includes approval and correction rates, overall accuracy, and field-level error statistics.
#
# Your goal is to generate a professional and formal summary **in Brazilian Portuguese (pt-BR)** that clearly describes the system's performance,
# without referencing internal teams or clients.
#
# This report will be shown to end-users via a download/view button in the interface, and it must reflect how well the system is functioning —
# especially in terms of accuracy, correction needs, and field-level behavior.
#
# Please use translated field display names as they appear on the front-end (in Portuguese), and **avoid using camelCase keys or technical terms**
# like "AI", "machine learning", or "model". This is a performance summary, not a technical document.
#
# ...
