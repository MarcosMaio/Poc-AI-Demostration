# %%
# %%capture
# %load_ext autoreload
# %autoreload 2
# %reset -f

# %% [markdown]
# #### **Import required libraries**

# %%
import setuptools  
import logging
import os
import json
from datetime import date

# %% [markdown]
# #### **Import utilities and configurations**

# %%
from agents import Agents
from helpers import (
    clean_agent_output,
    initialize_llm,
    extract_text_from_file
)
# Out:
# /home/marcos_maio/cads/poc-ai-demostration/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:623: UserWarning: <built-in function callable> is not a Python type (it may be an instance of an object), Pydantic will allow any object with no validation since we cannot even enforce that the input is an instance of the given type. To get rid of this error wrap the type with `pydantic.SkipValidation`.
#   warn(
# <frozen importlib._bootstrap>:488: DeprecationWarning: builtin type SwigPyPacked has no __module__ attribute
# <frozen importlib._bootstrap>:488: DeprecationWarning: builtin type SwigPyObject has no __module__ attribute
# <frozen importlib._bootstrap>:488: DeprecationWarning: builtin type swigvarlink has no __module__ attribute

# %% [markdown]
# #### **Model Config**

# %%
model: str = "gemini/gemini-2.5-pro"
api_key: str = os.getenv("GEMINI_API_KEY")
config_data = {
    "temperature": 0.1,
    "top_p": 0.85,
}

# %% [markdown]
# #### **Inicial Setup**

# %%
logger = logging.getLogger("poc_presentations")
llm_instance = initialize_llm(model, api_key, config_data)
agents_instance = Agents(llm_instance)

# %% [markdown]
# #### **Expected Input** (Use Case - Marketing Agents)

# %%
GenerateCampaignAgents=["ContentStrategistAgent", "PostPlannerAgent", "ComplianceReviewerAgent"]

GenerateCampaignInputs = {
    "subject": "Agentes de IA e como eles estão mudando o mundo.",
    "objective": "Engajamento",
    "language": "Portuguese",
    "platforms": ["linkedin", "instagram", "blog"],
    "brand": {},
    "current_date": date.today().isoformat()
}

# -------------------------------------------------------------------------------------------------------

GeneratePostContentAgents = ["PostContentCreatorAgent", "PostContentComplianceAgent"]

GeneratePostContentInputs = {
    "topic": "Agentes de IA: O Guia Definitivo Para Aumentar a Sua Produtividade",
    "platform": "blog",
    "description": (
        "Bem-vindo à nova era da produtividade. Se sente que as tarefas repetitivas e a sobrecarga de informação estão a consumir o seu tempo e energia, impedindo-o de se focar no que realmente importa, não está sozinho (Problema). Esta constante batalha contra tarefas administrativas não só causa frustração, como também representa um custo de oportunidade gigantesco: menos inovação, menos estratégia e um risco crescente de burnout (Agitação). É aqui que entram os Agentes de IA. Imagine ter uma equipa de assistentes digitais autónomos, capazes de pesquisar, analisar, resumir e executar tarefas complexas por si, 24/7. Eles não são apenas ferramentas de automação; são multiplicadores do seu potencial, libertando a sua mente para a criatividade, o pensamento crítico e a tomada de decisões estratégicas. Neste guia completo, vamos desmistificar o que são os Agentes de IA e mostrar como pode começar a usá-los hoje para transformar a sua forma de trabalhar e potenciar o seu talento (Solução). Vamos explorar juntos esta revolução."
    ),
    "keywords": [
        "agentes de ia",
        "inteligência artificial",
        "produtividade no trabalho",
        "automação inteligente",
        "futuro do trabalho",
        "tecnologia e carreira",
        "aumento de capacidade",
    ],
    "audience": "Profissionais curiosos sobre tecnologia e inovação",
    "custom_instructions": ""
} 

#-------------------------------------------------------------------------------------------------

DocumentHealthAnalyzerAgents = ["DocumentHealthAnalyzerAgent", "DocumentHealthComplianceAgent"]

DocumentHealthAnalyzerInputs = {
    "content_to_analyze": """ 
        # Agentes de IA: O Guia Definitivo Para Aumentar a Sua Produtividade

        A sua lista de tarefas parece interminável? Sente que passa mais tempo a gerir e-mails, a agendar reuniões e a compilar relatórios do que a fazer o trabalho estratégico que realmente importa? Se a sua resposta for "sim", não está sozinho. A sobrecarga de informação e as tarefas repetitivas são os ladrões silenciosos da produtividade no mundo profissional moderno.

        Esta sensação de estar constantemente a correr atrás do prejuízo não é apenas frustrante — é um obstáculo real ao seu crescimento. Impede-o de inovar, de pensar de forma crítica e de se focar no que pode verdadeiramente impulsionar a sua **tecnologia e carreira**. E no meio de tudo isto, surge uma pressão crescente para acompanhar a rápida evolução tecnológica, deixando muitos a pensar: "Estarei a ficar para trás?"

        E se lhe disséssemos que existe uma solução que não só resolve este problema, como também o coloca na vanguarda da inovação? Bem-vindo ao mundo dos **agentes de IA**. Eles são a chave para desbloquear um novo nível de eficiência e libertar o seu verdadeiro potencial.

        ### O que são, exatamente, os Agentes de IA?

        Esqueça os chatbots básicos que respondem a perguntas pré-programadas. Os agentes de IA (ou Agentes Autónomos) são muito mais do que isso. Pense neles como assistentes digitais proativos e inteligentes.

        Um agente de IA é um software que utiliza **inteligência artificial** para perceber o seu ambiente digital, tomar decisões de forma autónoma e executar ações complexas para atingir objetivos que lhe foram definidos. A grande diferença está na sua autonomia: em vez de esperar por um comando específico, um agente de IA pode receber um objetivo — como "organiza a minha viagem de negócios a São Paulo na próxima semana" — e tratar de tudo, desde a pesquisa de voos e hotéis até à marcação de reuniões e à adição dos eventos ao seu calendário.

        ### A Revolução na Produtividade no Trabalho: Exemplos Práticos

        A verdadeira magia acontece quando aplicamos esta tecnologia ao nosso dia a dia profissional. A **automação inteligente** proporcionada pelos agentes de IA vai muito além de simples macros ou filtros de e-mail. Veja como eles podem transformar a sua **produtividade no trabalho**:

        *   **Gestor de Comunicações Pessoal:** Imagine um agente que lê, prioriza e resume a sua caixa de entrada todas as manhãs. Ele pode redigir respostas a e-mails comuns, alertá-lo apenas para as mensagens urgentes e até mesmo gerir o agendamento de reuniões, negociando horários com outros assistentes (humanos ou IA) sem que precise de intervir.
        *   **Analista de Dados Incansável:** Precisa de um relatório sobre as últimas tendências do seu mercado? Em vez de passar horas a pesquisar, pode delegar essa tarefa a um agente de IA. Ele irá navegar na web, analisar artigos, compilar dados de mercado e apresentar-lhe um relatório estruturado com os principais insights.
        *   **Coordenador de Projetos Eficiente:** Atribua a um agente a tarefa de acompanhar o progresso de um projeto. Ele pode enviar lembretes automáticos aos membros da equipa, atualizar o status das tarefas em plataformas como o Asana ou o Trello e alertá-lo para potenciais bloqueios ou atrasos.
        *   **Assistente de Viagens e Logística:** Desde encontrar as melhores opções de voos e hotéis que cumprem a política da empresa até à gestão de despesas e à criação de itinerários detalhados, um agente de IA pode tratar de toda a logística aborrecida, libertando-o para se focar no objetivo da viagem.

        ### Mais do que Eficiência: O Aumento de Capacidade Humana

        O maior benefício dos agentes de IA não é apenas fazer mais em menos tempo. É o **aumento de capacidade** (human augmentation). Ao delegar as tarefas operacionais, repetitivas e demoradas, os profissionais ganham o recurso mais valioso de todos: tempo e espaço mental.

        Este novo tempo pode ser reinvestido em:

        *   **Pensamento Estratégico:** Analisar o panorama geral e tomar decisões mais informadas.
        *   **Criatividade e Inovação:** Desenvolver novas ideias e soluções para problemas complexos.
        *   **Relações Interpessoais:** Focar-se em construir relações mais fortes com clientes e colegas.
        *   **Desenvolvimento de Competências:** Aprender e crescer em áreas que realmente impulsionam a carreira.

        Os agentes de IA não o substituem. Eles capacitam-no, permitindo que opere no seu máximo potencial e se concentre no trabalho de alto valor que apenas os humanos podem fazer.

        ### O Futuro do Trabalho é Colaborativo

        O debate sobre a IA muitas vezes oscila entre a utopia e o medo da substituição. A realidade, no entanto, aponta para um caminho intermédio: a colaboração. O **futuro do trabalho** não será uma competição entre humanos e máquinas, mas uma simbiose.

        Aprender a comunicar, delegar e colaborar eficazmente com agentes de IA está rapidamente a tornar-se uma competência essencial. Os profissionais que dominarem estas ferramentas não só aumentarão drasticamente a sua própria produtividade, como também se tornarão ativos indispensáveis para qualquer organização que queira manter-se competitiva.

        A era dos agentes de IA já começou. Eles representam o próximo passo lógico na evolução das ferramentas de produtividade, uma evolução tão impactante como foi a passagem da máquina de escrever para o computador. Ignorá-los não é uma opção. Abraçá-los é o caminho para um futuro profissional mais inteligente, estratégico e, finalmente, mais humano.

        ---

        **E você? Que tarefa do seu dia a dia adoraria delegar a um agente de IA para poder focar-se no que realmente importa? Deixe o seu comentário abaixo!**

        **Gostou deste guia? Partilhe este artigo com a sua equipa e comece a conversa sobre o futuro da produtividade na sua empresa!**
        """
}

#----------------------------------------------------------------------------------------------------------

GenerateBrandBriefAgents = ["WebsiteBrandBriefAgent", "BrandBriefComplianceAgent"]

GenerateBrandBriefInputs = {
    "website_url":  "https://www.marica.rj.gov.br/"
}

# %% [markdown]
# #### **Expected Input** (Use Case - Análise Comparison About Data Extraction Agents)

# %%
ExtractionAccuracyAnalyzeAgents = ["ExtractionEvaluatorAgent"]

ExtractionAccuracyAnalyzeInputs = {
    "template": extract_text_from_file("extraction_comparison_use_cases", "template.json"),  
    "agents_response_to_analyze": extract_text_from_file("extraction_comparison_use_cases", "agents_response.json"),
    "rules_to_follow": extract_text_from_file("extraction_comparison_use_cases", "general_rules.md"),
    "llm": "gemini-2.5-pro"  
}
print("Inputs for Extraction Accuracy Analyze Agents:")
print(json.dumps(ExtractionAccuracyAnalyzeInputs, indent=2, ensure_ascii=False))
# Out:
# Inputs for Extraction Accuracy Analyze Agents:
# {
# ...

# %% [markdown]
# #### **Process Agent**

# %%
try:    
    final_output = clean_agent_output(
        agents_instance.workflow(
            agent_keys=ExtractionAccuracyAnalyzeAgents,
            inputs=ExtractionAccuracyAnalyzeInputs
        )
    )

    if not isinstance(final_output, (list, dict, str)):
        raise ValueError("Invalid type returned from callAgents.")
        
except Exception as e:
    logger.error(f"Error during information extraction: {e}")
    raise

print(
    f"\n**Agente Result:**\n",
    json.dumps(final_output, indent=4, ensure_ascii=False)
)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 9677f053-09e1-4bec-9d86-b3292a533d02                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ...
